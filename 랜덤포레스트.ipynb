# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

style.use('seaborn-talk')

krfont = {'family':'Malgun Gothic','weight':'bold','size':10}
matplotlib.rc('font',**krfont)
matplotlib.rcParams['axes.unicode_minus']=False

# %%
huji = pd.read_csv("plz.csv",encoding='euc=kr')
huji
# Out:
#      시군산지    연도   월    시점          일자  품목      품종 광역산지  도매가격.원.kg.  거래량.톤.  \
# 0      강릉  2016   3  2016  2016-07-02  마늘  햇마늘 한지   강원        2500   0.040
# 1      강릉  2017  10  2018  2018-01-30  마늘     풋마늘   강원        6900   0.030
# 2      강릉  2017  10  2018  2018-01-16  마늘     깐마늘   강원        7573   0.030
# 3      강릉  2017  10  2018  2018-02-07  마늘     깐마늘   강원        6400   0.002
# 4      강릉  2017  10  2018  2018-01-16  마늘     풋마늘   강원        6906   0.020
# ...   ...   ...  ..   ...         ...  ..     ...  ...         ...     ...
# 1446   홍천  2020   4  2020  2020-07-30  마늘     깐마늘   강원        5250   2.000
# 1447   홍천  2020   4  2020  2020-07-14  마늘     깐마늘   강원        5250   1.000
# 1448   홍천  2020   5  2020  2020-08-12  마늘     깐마늘   강원        5250   2.000
# 1449   홍천  2020   7  2020  2020-10-29  마늘     풋마늘   강원        2808   0.030
# 1450   홍천  2020   7  2020  2020-11-05  마늘      기타   강원        5625   0.008
#
# ...

# %%
huji = huji.set_index('일자')

# %%
huji.columns
# Out:
# Index(['시군산지', '연도', '월', '시점', '품목', '품종', '광역산지', '도매가격.원.kg.', '거래량.톤.',
#        '거래금액.백만원.', '마늘.면적..ha.', 'X10a당.생산량..kg.', '생산량..톤.', 'X10a당.생산량.톤',
#        '평균', '평균기온..C.', '평균상대습도...', '월합강수량.00.24h만..mm.', '합계.일조시간.hr.'],
#       dtype='object')

# %%
huji
# Out:
#            시군산지    연도   월    시점  품목      품종 광역산지  도매가격.원.kg.  거래량.톤.  \
# 일자
# 2016-07-02   강릉  2016   3  2016  마늘  햇마늘 한지   강원        2500   0.040
# 2018-01-30   강릉  2017  10  2018  마늘     풋마늘   강원        6900   0.030
# 2018-01-16   강릉  2017  10  2018  마늘     깐마늘   강원        7573   0.030
# 2018-02-07   강릉  2017  10  2018  마늘     깐마늘   강원        6400   0.002
# 2018-01-16   강릉  2017  10  2018  마늘     풋마늘   강원        6906   0.020
# ...         ...   ...  ..   ...  ..     ...  ...         ...     ...
# 2020-07-30   홍천  2020   4  2020  마늘     깐마늘   강원        5250   2.000
# 2020-07-14   홍천  2020   4  2020  마늘     깐마늘   강원        5250   1.000
# 2020-08-12   홍천  2020   5  2020  마늘     깐마늘   강원        5250   2.000
# 2020-10-29   홍천  2020   7  2020  마늘     풋마늘   강원        2808   0.030
# 2020-11-05   홍천  2020   7  2020  마늘      기타   강원        5625   0.008
#
#             거래금액.백만원.  마늘.면적..ha.  X10a당.생산량..kg.  생산량..톤.  X10a당.생산량.톤  \
# 일자
# ...

# %%
x = huji[['거래량.톤.',
       '거래금액.백만원.', '마늘.면적..ha.', 'X10a당.생산량..kg.', '생산량..톤.', 'X10a당.생산량.톤',
       '평균', '평균기온..C.', '평균상대습도...', '월합강수량.00.24h만..mm.', '합계.일조시간.hr.']].values
y = huji['도매가격.원.kg.']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
x
# Out:
# array([[4.000e-02, 1.000e-01, 1.800e+02, ..., 4.900e+01, 2.930e+01,
#         2.070e+02],
#        [3.000e-02, 1.900e-01, 2.650e+02, ..., 6.700e+01, 1.145e+02,
#         1.526e+02],
#        [3.000e-02, 2.300e-01, 2.650e+02, ..., 6.700e+01, 1.145e+02,
#         1.526e+02],
#        ...,
#        [2.000e+00, 1.050e+01, 2.360e+02, ..., 7.000e+01, 1.050e+02,
#         1.851e+02],
#        [3.000e-02, 7.000e-02, 2.360e+02, ..., 7.800e+01, 2.139e+02,
#         1.300e+02],
#        [8.000e-03, 5.000e-02, 2.360e+02, ..., 7.800e+01, 2.139e+02,
#         1.300e+02]])

# %%
y
# Out:
# 일자
# 2016-07-02    2500
# 2018-01-30    6900
# 2018-01-16    7573
# 2018-02-07    6400
# 2018-01-16    6906
#               ...
# 2020-07-30    5250
# 2020-07-14    5250
# 2020-08-12    5250
# 2020-10-29    2808
# 2020-11-05    5625
# Name: 도매가격.원.kg., Length: 1451, dtype: int64

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 1015
# 436
# 1015
# 436

# %%
forest = RandomForestRegressor(n_estimators=1000,criterion='mse',random_state=1,n_jobs=-1)
forest.fit(x_train,y_train)
y_train_pred = forest.predict(x_train)
y_test_pred = forest.predict(x_test)

r2_train = r2_score(y_train,y_train_pred)
r2_test = r2_score(y_test,y_test_pred)

print('훈련 R^2: %.3f, 테스트 R^2: %.3f'%(r2_train,r2_test))
# Out:
# 훈련 R^2: 0.963, 테스트 R^2: 0.845
